# %%
import env
import numpy as np
import pandas as pd
from pydataset import data

# %%
def get_db_url(user,password,host,database):
    return f'mysql+pymysql://{user}:{password}@{host}/{database}'

# %%
url = get_db_url(env.user,env.password,env.host,'employees')

# %%
query = 'select * from employees limit 10'

# %%
url_typo = get_db_url(user,password,host,'employeess')
url_typo
# Out:
# 'mysql+pymysql://robinson_2289:YYxwAT9m2guld6bsEHpjenVRfObPzMdC@data.codeup.com/employeess'

# %%
df = pd.read_sql(query,url_typo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_sql(query,url_typo)
#
# NameError: name 'url_typo' is not defined

# %%
query_typo= 'select * from employees limit 10z'

# %%
df = pd.read_sql(query_typo,url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_sql(query_typo,url)
#
# NameError: name 'query_typo' is not defined

# %%
titles_query = 'select * from titles'

# %%
employees_df = pd.read_sql(query,url)
titles_df = pd.read_sql(titles_query,url)
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
employees_df.shape
# Out:
# (10, 6)

# %%
titles_df.shape
# Out:
# (443308, 4)

# %%
len(titles_df.title.unique())
# Out:
# 7

# %%
employees_df.describe()
# Out:
#             emp_no
# count     10.00000
# mean   10005.50000
# std        3.02765
# min    10001.00000
# 25%    10003.25000
# 50%    10005.50000
# 75%    10007.75000
# max    10010.00000

# %%
titles_df.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
titles_df['to_date'].min()
# Out:
# datetime.date(1985, 3, 1)

# %%
titles_df['to_date'].max()
# Out:
# datetime.date(9999, 1, 1)

# %%
recent_date = 'select * from titles where to_date < now()'

# %%
recent_date_df = pd.read_sql(recent_date,url)

recent_date_df['to_date'].max()
# Out:
# datetime.date(2002, 8, 1)

# %% [markdown]
# ### Exercise 2
# 1. Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='id', right_on='id',how='right',indicator=True)
# Out:
#    id name_x  role_id     name_y _merge
# 0   1    bob      1.0      admin   both
# 1   2    joe      2.0     author   both
# 2   3  sally      3.0   reviewer   both
# 3   4   adam      3.0  commenter   both

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='id', right_on='id',how='outer',indicator=True)
# Out:
#    id name_x  role_id     name_y     _merge
# 0   1    bob      1.0      admin       both
# 1   2    joe      2.0     author       both
# 2   3  sally      3.0   reviewer       both
# 3   4   adam      3.0  commenter       both
# 4   5   jane      NaN        NaN  left_only
# 5   6   mike      NaN        NaN  left_only

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
drop_roles = roles.drop(columns='id')
drop_roles
# Out:
#         name
# 0      admin
# 1     author
# 2   reviewer
# 3  commenter

# %%
drop_users = drop_roles.merge(drop_roles, left_on='name', right_on='name',how='outer',indicator=True)
# still able to merge, with or without foreign key

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
mpg = data('mpg')
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
mpg = mpg.rename(columns={'displ':'dispacement'})

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#        dispacement         year         cyl         cty         hwy
# count   234.000000   234.000000  234.000000  234.000000  234.000000
# mean      3.471795  2003.500000    5.888889   16.858974   23.440171
# std       1.291959     4.509646    1.611534    4.255946    5.954643
# min       1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%       2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%       3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%       4.600000  2008.000000    8.000000   19.000000   27.000000
# max       7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg
# Out:
#     manufacturer   model  dispacement  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4          1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4          1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4          2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4          2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4          2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...          ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat          2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat          2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat          2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat          2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat          3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# ...

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
mpg['manufacturer'].nunique()
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
mpg['model'].nunique()
#11
# Out:
# 38

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg['hwy'] - mpg['cty']
mpg
# Out:
#     manufacturer   model  dispacement  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4          1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4          1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4          2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4          2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4          2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...          ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat          2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat          2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat          2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat          2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat          3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# ...

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg['cty'] + mpg['hwy']) / 2
mpg
# Out:
#     manufacturer   model  dispacement  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4          1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4          1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4          2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4          2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4          2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...          ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat          2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat          2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat          2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat          2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat          3.6  2008    6    auto(s6)   f   17   26  p
#
# ...

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_auto'] = np.where(mpg['trans'].str.contains('auto'),True,False)
mpg
# Out:
#     manufacturer   model  dispacement  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4          1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4          1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4          2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4          2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4          2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...          ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat          2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat          2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat          2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat          2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat          3.6  2008    6    auto(s6)   f   17   26  p
#
# ...

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
manu_avgmile = pd.concat([mpg['manufacturer'], mpg['average_mileage']], axis=1)

manu_avgmile.groupby(['manufacturer'])

# %%
highest_avg_miles = manu_avgmile.groupby(['manufacturer'])['average_mileage'].mean().sort_values(ascending=False)
highest_avg_miles
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_auto')['average_mileage'].mean()
# They do not
# Out:
# is_auto
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %% [markdown]
# ### Exercises III
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url_chipotle = get_db_url(env.user,env.password,env.host,'chipotle')
query_chipotle = 'select * from orders'
chipotle = pd.read_sql(query_chipotle,url_chipotle)
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %% [markdown]
# 2. What is the total price for each order?

# %%
chipotle['item_price'] = chipotle['item_price'].str.replace(',','')
chipotle['item_price'] = chipotle['item_price'].str.replace('$','')
chipotle['item_price'] = chipotle['item_price'].astype('float')

# %%
chipotle.groupby('order_id')['item_price'].sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
pd.crosstab(chipotle.item_name,chipotle.quantity,margins=True)
#726 Chicken bowls, 553 Chicken burritos, 479 Chips and guac
# Out:
# quantity                                  1    2   3   4  5  7  8  10  15  \
# item_name
# 6 Pack Soft Drink                        53    1   0   0  0  0  0   0   0
# Barbacoa Bowl                            66    0   0   0  0  0  0   0   0
# Barbacoa Burrito                         91    0   0   0  0  0  0   0   0
# Barbacoa Crispy Tacos                    10    1   0   0  0  0  0   0   0
# Barbacoa Salad Bowl                      10    0   0   0  0  0  0   0   0
# Barbacoa Soft Tacos                      25    0   0   0  0  0  0   0   0
# Bottled Water                           139   12   6   2  1  1  0   1   0
# Bowl                                      1    0   1   0  0  0  0   0   0
# Burrito                                   6    0   0   0  0  0  0   0   0
# Canned Soda                              84   19   0   1  0  0  0   0   0
# Canned Soft Drink                       264   27   7   3  0  0  0   0   0
# ...

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
#chipotle.pivot_table(index='quantity',columns='item_name',values='item_price')

# %%
chipotle.groupby('item_name')['item_price'].sum().sort_values(ascending=False).head()
#chicken bowl
# Out:
# item_name
# Chicken Bowl           7342.73
# Chicken Burrito        5575.82
# Steak Burrito          3851.43
# Steak Bowl             2260.19
# Chips and Guacamole    2201.04
# Name: item_price, dtype: float64

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
url_employees = get_db_url(env.user,env.password,env.host,'employees')
query_employees = 'select * from employees'
query_titles = 'select * from titles'
employees = pd.read_sql(query_employees,url_employees)
titles = pd.read_sql(query_titles,url_employees)

# %%
employees.sample(3)
titles.sample(3)
# Out:
#         emp_no         title   from_date     to_date
# 215710  245810  Senior Staff  1986-03-08  9999-01-01
# 208995  241262      Engineer  1993-02-19  2001-02-19
# 284996  292740      Engineer  1988-03-03  1996-03-03

# %%
emp_titles = employees.merge(titles, how='inner', on='emp_no')
emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_titles.groupby('title')['from_date'].max()
# Out:
# title
# Assistant Engineer    2000-02-01
# Engineer              2002-08-01
# Manager               1996-08-30
# Senior Engineer       2002-08-01
# Senior Staff          2002-08-01
# Staff                 2000-02-01
# Technique Leader      2000-02-01
# Name: from_date, dtype: object

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
query_departments = 'select * from departments'
query_deptemp = 'select dept_no, emp_no from dept_emp'
dp = pd.read_sql(query_departments, url_employees)
dpe = pd.read_sql(query_deptemp, url_employees)
dp
# Out:
#   dept_no           dept_name
# 0    d009    Customer Service
# 1    d005         Development
# 2    d002             Finance
# 3    d003     Human Resources
# 4    d001           Marketing
# 5    d004          Production
# 6    d006  Quality Management
# 7    d008            Research
# 8    d007               Sales

# %%
demp_titles = emp_titles.merge(dpe, how='right', on='emp_no')
demp_titles
# Out:
#         emp_no  birth_date first_name  last_name gender   hire_date  \
# 0        10017  1958-07-06  Cristinel  Bouloucos      F  1993-08-03
# 1        10017  1958-07-06  Cristinel  Bouloucos      F  1993-08-03
# 2        10055  1956-06-06     Georgy     Dredge      M  1992-04-27
# 3        10058  1954-10-01    Berhard   McFarlin      M  1987-04-13
# 4        10108  1952-04-07     Lunjin     Giveon      M  1986-10-02
# ...        ...         ...        ...        ...    ...         ...
# 489898  499978  1960-03-29  Chiranjit    Kuzuoka      M  1990-05-24
# 489899  499982  1954-08-25   Mohammed   Pleszkun      M  1986-02-21
# 489900  499983  1955-08-29        Uri     Juneja      F  1989-08-28
# 489901  499983  1955-08-29        Uri     Juneja      F  1989-08-28
# 489902  499991  1962-02-26      Pohua    Sichman      F  1989-01-12
#
#                title   from_date     to_date dept_no
# 0       Senior Staff  2000-08-03  9999-01-01    d001
# ...

# %%
pd.crosstab(index=dp.dept_name,columns=emp_titles.title)
# Out:
# title               Engineer  Senior Engineer  Senior Staff  Staff
# dept_name
# Customer Service           0                1             0      0
# Development                0                0             0      1
# Finance                    0                1             0      0
# Human Resources            1                0             0      0
# Marketing                  0                1             0      0
# Production                 0                0             1      0
# Quality Management         0                0             0      1
# Research                   0                1             0      0
# Sales                      0                0             1      0
